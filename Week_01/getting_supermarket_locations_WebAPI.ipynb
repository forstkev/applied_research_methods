# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/applied_research_methods/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#       5 query = f"""
#       6         [out:json];
#       7         area["ISO3166-1"="CH"][admin_level=2];
#       8         node ["shop"="supermarket"](area);
#       9         out;"""
#      11 # Web API request
# ---> 12 r = requests.get(url, params={'data': query})
#      13 data = r.json()['elements']
#      15 # Save data to file
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47a35ae2b923dc936b66a0a3cf433cfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47a35ae2b923dc936b66a0a3cf433cfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47a35ae2b923dc936b66a0a3cf433cfd = L.map(
#                 &quot;map_47a35ae2b923dc936b66a0a3cf433cfd&quot;,
#                 {
#                     center: [47.00762479853574, 7.995197778983636],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#
#
#
#             var tile_layer_b2546969bf1c5d704d4b0dd2372f164a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b2546969bf1c5d704d4b0dd2372f164a.addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#             var marker_1b0fac3ee8ca5605e4eb78e1f1345a7a = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#         var popup_d946d0f7db4ed57df136e69899f51b2c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_590ba38bb13e4f2978b5065cdb6f5e04 = $(`&lt;div id=&quot;html_590ba38bb13e4f2978b5065cdb6f5e04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_d946d0f7db4ed57df136e69899f51b2c.setContent(html_590ba38bb13e4f2978b5065cdb6f5e04);
#
#
#
#         marker_1b0fac3ee8ca5605e4eb78e1f1345a7a.bindPopup(popup_d946d0f7db4ed57df136e69899f51b2c)
#         ;
#
#
#
#
#             var marker_874761a4a95deabc832abb60e06c3d68 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#         var popup_3b46d135952fdc3312eda4b6db214734 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e6d3228b1cfb03fb2948f7dd6efc88a2 = $(`&lt;div id=&quot;html_e6d3228b1cfb03fb2948f7dd6efc88a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_3b46d135952fdc3312eda4b6db214734.setContent(html_e6d3228b1cfb03fb2948f7dd6efc88a2);
#
#
#
#         marker_874761a4a95deabc832abb60e06c3d68.bindPopup(popup_3b46d135952fdc3312eda4b6db214734)
#         ;
#
#
#
#
#             var marker_03ff3dbe4c53b9947f75196ea15cc4c2 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#         var popup_2c6313056abb766eabf6eca8e08d3710 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_895ac3ba15b8a6ceea39a0dd0df253b8 = $(`&lt;div id=&quot;html_895ac3ba15b8a6ceea39a0dd0df253b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_2c6313056abb766eabf6eca8e08d3710.setContent(html_895ac3ba15b8a6ceea39a0dd0df253b8);
#
#
#
#         marker_03ff3dbe4c53b9947f75196ea15cc4c2.bindPopup(popup_2c6313056abb766eabf6eca8e08d3710)
#         ;
#
#
#
#
#             var marker_acc83539ec2166d1e3da091da1b4bfe9 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#         var popup_d2f74670d676190cc7cacd36fb196756 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1cad7f3b88ca1c78ad534ce3cdce3bb2 = $(`&lt;div id=&quot;html_1cad7f3b88ca1c78ad534ce3cdce3bb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_d2f74670d676190cc7cacd36fb196756.setContent(html_1cad7f3b88ca1c78ad534ce3cdce3bb2);
#
#
#
#         marker_acc83539ec2166d1e3da091da1b4bfe9.bindPopup(popup_d2f74670d676190cc7cacd36fb196756)
#         ;
#
#
#
#
#             var marker_b99b9f2fa971f1bcc2294627a93cf958 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_47a35ae2b923dc936b66a0a3cf433cfd);
#
#
#         var popup_192c21beac3ccd9f84835bb1731641e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f3311f32bbf671c7ee2ecc840a0565d4 = $(`&lt;div id=&quot;html_f3311f32bbf671c7ee2ecc840a0565d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_192c21beac3ccd9f84835bb1731641e8.setContent(html_f3311f32bbf671c7ee2ecc840a0565d4);
#
#
#
#         marker_b99b9f2fa971f1bcc2294627a93cf958.bindPopup(popup_192c21beac3ccd9f84835bb1731641e8)
#         ;
#
#
#
#
#             var marker_e1e081d02c6b44883042ea7644ebdcbf = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
